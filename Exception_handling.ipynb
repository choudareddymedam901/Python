# %%
a=10
a/20
# Out:
# 0.5

# %%
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a/0
#
# ZeroDivisionError: division by zero

# %%
try:
    f=open("test.txt","r")
    f.write("hello")
except Exception as e:
    print("There is some issue",e)
print("this is my code")
# Out:
# There is some issue [Errno 2] No such file or directory: 'test.txt'
# this is my code

# %%
try:
    f=open("text1.txt","w")
    f.write("This is my code in try block")
except Exception as e:
    print("This will handle an error",e)
else:
    print("this will execute once my try block will run sucessfully")
    f.close()
# Out:
# this will execute once my try block will run sucessfully

# %%
try:
    f=open("text1.txt","w")
    f.write("This is my code in try block1")
except Exception as e:
    print("This will handle an error",e)
finally:
    print("code is running successfully")
    f.close()
# Out:
# code is running successfully

# %%
def askint():
    flag=True
    while flag:
        try:
            a=int(input())
            if type(a) == int:
                return a
                flag=False
        except Exception as e:
            print(e)

# %%
askint()
# Out:
#  wegdv
# invalid literal for int() with base 10: 'wegdv'
#  sdfs
# invalid literal for int() with base 10: 'sdfs'
#  aefaf
# invalid literal for int() with base 10: 'aefaf'
#  afafaf
# invalid literal for int() with base 10: 'afafaf'
#  asfaf
# invalid literal for int() with base 10: 'asfaf'
#  afaf
# invalid literal for int() with base 10: 'afaf'
#  1
# 1

# %%
def test(a):
    if a<0:
        raise Exception("You have entered Negative values",a)
    return a

# %%
test(-1)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 test(-1)
#
# Cell In[29], line 3, in test(a)
#       1 def test(a):
#       2     if a<0:
# ----> 3         raise Exception("You have entered Negative values",a)
#       4     return a
#
# Exception: ('You have entered Negative values', -1)
