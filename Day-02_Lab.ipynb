# %%
a = "Rock"

# %%
a
# Out:
# 'Rock'

# %%
type(a)
# Out:
# str

# %%
a[0]
# Out:
# 'R'

# %%
a[1]
# Out:
# 'o'

# %%
a[2]
# Out:
# 'c'

# %%
a[3]
# Out:
# 'k'

# %%
a[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a[4]
#
# IndexError: string index out of range

# %%
a[-1]
# Out:
# 'k'

# %%
a[-2]
# Out:
# 'c'

# %%
a[-3]
# Out:
# 'o'

# %%
a[-4]
# Out:
# 'R'

# %%
a[-5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a[-5]
#
# IndexError: string index out of range

# %%
a[0:1]
# Out:
# 'R'

# %%
a[0:4]
# Out:
# 'Rock'

# %%
a[0:201]
# Out:
# 'Rock'

# %%
a[-1:4]
# Out:
# 'k'

# %%
a[0:-2]
# Out:
# 'Ro'

# %%
a[-1:-2]
# Out:
# ''

# %%
a[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a[1]
#
# NameError: name 'a' is not defined

# %%
a="Rock"

# %%
a[1]
# Out:
# 'o'

# %%
a.find('c')
# Out:
# 2

# %%
a.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a.count()
#
# TypeError: count expected at least 1 argument, got 0

# %%
a.count('c')
# Out:
# 1

# %%
c = "I am choudareddy medam"

# %%
c
# Out:
# 'I am choudareddy medam'

# %%
c.split()
# Out:
# ['I', 'am', 'choudareddy', 'medam']

# %%
l=c.split()

# %%
l
# Out:
# ['I', 'am', 'choudareddy', 'medam']

# %%
l[0]
# Out:
# 'I'

# %%
c= "chinna"

# %%
c.replace('a','u')
# Out:
# 'chinnu'

# %%
"chouda\treddy".expandtabs()
# Out:
# 'chouda  reddy'

# %%
c
# Out:
# 'chinna'

# %%
c.center(50,'@')
# Out:
# '@@@@@@@@@@@@@@@@@@@@@@chinna@@@@@@@@@@@@@@@@@@@@@@'

# %%
l1=[10,20,"abc",29]

# %%
l1
# Out:
# [10, 20, 'abc', 29]

# %%
l1.append("chinna")

# %%
l1
# Out:
# [10, 20, 'abc', 29, 'chinna']

# %%
l1.pop()
# Out:
# 'chinna'

# %%
l1
# Out:
# [10, 20, 'abc', 29]

# %%
l1.insert(1,"chinna")

# %%
l1
# Out:
# [10, 'chinna', 20, 'abc', 29]

# %%
l1.reverse()

# %%
l1
# Out:
# [29, 'abc', 20, 'chinna', 10]

# %%
l1.count(10)
# Out:
# 2

# %%
l1.append(10)

# %%
l1.extend([10,20,30,40,50,60])

# %%
l1
# Out:
# [29, 'abc', 20, 'chinna', 10, 10, 10, 20, 30, 40, 50, 60]
