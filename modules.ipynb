# %%
import os

# %%
os.getlogin()
# Out:
# 'choud'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is E88F-2898
#
#  Directory of C:\Users\choud
#
# 2026-05-19  06:17 AM    <DIR>          .
# 2026-03-31  06:11 AM    <DIR>          ..
# 2026-04-28  08:47 AM    <DIR>          .anaconda
# 2024-03-18  10:55 PM    <DIR>          .android
# 2021-11-30  11:56 AM    <DIR>          .astropy
# 2025-01-30  07:06 AM    <DIR>          .aws
# 2025-08-27  06:15 AM            14,249 .bash_history
# 2022-11-20  08:44 AM    <DIR>          .cache
# 2026-04-29  06:14 AM    <DIR>          .conda
# 2021-10-23  03:55 AM                25 .condarc
# 2024-10-14  05:09 PM    <DIR>          .config
# 2026-04-28  08:53 AM    <DIR>          .continuum
# 2021-08-18  08:47 AM               237 .dbshell
# 2024-02-26  03:42 PM    <DIR>          .eclipse
# 2026-02-22  10:36 PM               145 .gitconfig
# 2023-12-04  09:41 AM                53 .git-for-windows-updater
# 2025-10-17  06:20 AM    <DIR>          .gk
# ...

# %%
import module

# %%
module.add(1,2)
# Out:
# 3

# %%
from module import add

# %%
module.add(123,321)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 module.add(123,321)
#
# NameError: name 'module' is not defined

# %%
add(180,32)
# Out:
# 212

# %%
add()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 add()
#
# NameError: name 'add' is not defined

# %%
import courses

# %%
courses.get_course()
# Out:
# ['data science', 'blockchain', 'cloud']

# %%
courses.data
# Out:
# {'name': 'ineuron',
#  'courses': ['data science', 'blockchain', 'cloud'],
#  'greetings': 'greetings from ineuron'}

# %%
courses.greetings()
# Out:
# 'greetings from ineuron'
