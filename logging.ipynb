# %%
import logging

# %%
logging.basicConfig(filename="test.log",level=logging.INFO)

# %%
pwd
# Out:
# 'C:\\Users\\choud'

# %%
pwd()
# Out:
# 'C:\\Users\\choud'

# %%
logging.info("This is my Information")
logging.warning("This is my Warning")
logging.error("This is my error")

# %%
logging.shutdown()

# %%
import logging
logging.basicConfig(filename="test2.log",level=logging.DEBUG, format='%(asctime)s %(message)s')

# %%
logging.info("This is my Information")
logging.warning("This is my Warning")
logging.debug("This is for debugging")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'acstime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'acstime'
# Call stack:
#   File "C:\Users\choud\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\choud\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\choud\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\choud\anaconda3\Lib\asyncio\base_events.py", line 2050, in _run_once
#     handle._run()
#   File "C:\Users\choud\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 602, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\choud\AppData\Local\Temp\ipykernel_22860\3491542990.py", line 1, in <module>
#     logging.info("This is my Information")
# Message: 'This is my Information'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'acstime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'acstime'
# Call stack:
#   File "C:\Users\choud\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\choud\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\choud\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\choud\anaconda3\Lib\asyncio\base_events.py", line 2050, in _run_once
#     handle._run()
#   File "C:\Users\choud\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 602, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\choud\AppData\Local\Temp\ipykernel_22860\3491542990.py", line 2, in <module>
#     logging.warning("This is my Warning")
# Message: 'This is my Warning'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 472, in format
#     return self._format(record)
#            ~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 468, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'acstime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 715, in format
#     s = self.formatMessage(record)
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 684, in formatMessage
#     return self._style.format(record)
#            ~~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "C:\Users\choud\anaconda3\Lib\logging\__init__.py", line 474, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'acstime'
# Call stack:
#   File "C:\Users\choud\anaconda3\Lib\runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\choud\anaconda3\Lib\runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\choud\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#     self._run_once()
#   File "C:\Users\choud\anaconda3\Lib\asyncio\base_events.py", line 2050, in _run_once
#     handle._run()
#   File "C:\Users\choud\anaconda3\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 519, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 508, in process_one
#     await dispatch(*args)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 400, in dispatch_shell
#     await result
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 368, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 455, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\choud\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 602, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\choud\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\choud\AppData\Local\Temp\ipykernel_22860\3491542990.py", line 3, in <module>
#     logging.debug("This is for debugging")
# Message: 'This is for debugging'
# Arguments: ()

# %%
import logging

logging.basicConfig(
    filename="test3.log",
    level=logging.DEBUG,
    format='%(asctime)s %(levelname)s %(message)s'
)

logging.info("This is my Information")
logging.warning("This is my Warning")
logging.debug("This is for debugging")

# %%
import logging
logging.basicConfig(filename="test4.log", level=logging.DEBUG, format = '%(asctime)s %(levelname)s %(message)s')

# %%
def divisonSum(a,b):
    logging.info("This is the start of the code i want to enter %s and %s", a,b)
    try:
        div = a/b
        logging.info("Executed Successfully")
    except Exception as e:
        logging.error("Error happened")
        logging.exception("Exception occured" + str(e))

# %%
divisonSum(1,0)
